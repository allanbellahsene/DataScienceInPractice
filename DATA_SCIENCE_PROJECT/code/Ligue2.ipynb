# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functions import *

# %%
path = '/Users/allanbellahsene/Desktop/FOOTBALL_PREDICTION_PROJECT/data/LIGUE_2/Ligue2_'
years = ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
         '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
L2 = import_data(path, years)

# %%
bm_accuracy=[]
for i in range(10, len(L2)):
    bm_accuracy.append(bookmaker_accuracy(L2[i], 'Bet365' ))

# %%
interval=['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
bar_chart(bm_accuracy,interval)

# %%
for i in range(10, len(L2)):
    print(bookmaker_accuracy(L2[i], 'Bet365'), bookmaker_accuracy(L2[i], 'Bet&Win'))
# Out:
# 0.45526315789473687 0.4605263157894737
# 0.45 0.45789473684210524
# 0.4356955380577428 0.43832020997375326
# 0.4868421052631579 0.4868421052631579
# 0.4473684210526316 0.4368421052631579
# 0.4421052631578947 0.45263157894736844
# 0.45526315789473687 0.45526315789473687
# 0.5210526315789473 0.5263157894736842
# 0.4394736842105263 0.45
# 0.42857142857142855 0.43333333333333335

# %%
L2[10]
# Out:
#     Div      Date               HomeTeam               AwayTeam  FTHG  FTAG  \
# 0    F2  06/08/10                Ajaccio                  Nimes     1     0
# 1    F2  06/08/10               Boulogne               Clermont     1     1
# 2    F2  06/08/10            Chateauroux                 Istres     0     0
# 3    F2  06/08/10                  Dijon                 Angers     0     0
# 4    F2  06/08/10               Grenoble               Le Havre     1     0
# 5    F2  06/08/10                   Metz  Evian Thonon Gaillard     0     2
# 6    F2  06/08/10                  Reims                  Laval     1     1
# 7    F2  06/08/10                  Tours                  Sedan     4     3
# 8    F2  06/08/10                 Vannes                 Troyes     1     0
# 9    F2  09/08/10                 Nantes                Le Mans     0     2
# 10   F2  13/08/10                 Angers               Boulogne     0     0
# ...

# %%
L2[10].iloc[0][['HomeTeam','AwayTeam', 'FTHG', 'FTAG','FTR']][0]
# Out:
# 'Ajaccio'

# %%
L2[10].iloc[0]['HomeTeam']
# Out:
# 'Ajaccio'

# %%
def show_F2F(data, team_1, team_2):
    for i in range(len(data)):
        for j in range(len(data[i])):
            if data[i].iloc[j]['HomeTeam'] == team_1 and data[i].iloc[j]['AwayTeam'] == team_2 or data[i].iloc[j]['HomeTeam'] == team_2 and data[i].iloc[j]['AwayTeam'] == team_1:
                print(data[i].iloc[j][['Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR']])

# %%
show_F2F(L2, 'Tours', 'Sedan')
# Out:
# Date        01/08/08
# HomeTeam       Tours
# AwayTeam       Sedan
# FTHG               2
# FTAG               1
# FTR                H
# Name: 7, dtype: object
# Date        29/05/09
# HomeTeam       Sedan
# AwayTeam       Tours
# FTHG               2
# FTAG               0
# FTR                H
# Name: 378, dtype: object
# Date        16/10/09
# HomeTeam       Sedan
# AwayTeam       Tours
# FTHG               2
# FTAG               0
# FTR                H
# Name: 97, dtype: object
# Date        12/03/10
# HomeTeam       Tours
# AwayTeam       Sedan
# FTHG               1
# FTAG               3
# FTR                A
# Name: 276, dtype: object
# Date        06/08/10
# HomeTeam       Tours
# AwayTeam       Sedan
# FTHG               4
# FTAG               3
# FTR                H
# Name: 7, dtype: object
# Date        27/05/11
# HomeTeam       Sedan
# AwayTeam       Tours
# FTHG               1
# FTAG               0
# FTR                H
# Name: 378, dtype: object
# ...

# %%
for i in range(len(L2)):
    for j in range(len(L2[i])):
        if L2[i].iloc[j]['HomeTeam'] == 'Ajaccio' and L2[i].iloc[j]['AwayTeam'] == 'Nimes' or L2[i].iloc[j]['HomeTeam'] == 'Nimes' and L2[i].iloc[j]['AwayTeam'] == 'Ajaccio':
            print(L2[i].iloc[j][['Date','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR']])
# Out:
# Date        14/11/00
# HomeTeam     Ajaccio
# AwayTeam       Nimes
# FTHG               1
# FTAG               0
# FTR                H
# Name: 189, dtype: object
# Date        27/03/01
# HomeTeam       Nimes
# AwayTeam     Ajaccio
# FTHG               1
# FTAG               0
# FTR                H
# Name: 323, dtype: object
# Date        28/11/01
# HomeTeam     Ajaccio
# AwayTeam       Nimes
# FTHG               3
# FTAG               1
# FTR                H
# Name: 171, dtype: object
# Date        14/04/02
# HomeTeam       Nimes
# AwayTeam     Ajaccio
# FTHG               0
# FTAG               1
# FTR                A
# Name: 359, dtype: object
# Date        26/09/08
# HomeTeam       Nimes
# AwayTeam     Ajaccio
# FTHG               2
# FTAG               2
# FTR                D
# Name: 72, dtype: object
# Date        07/03/09
# HomeTeam     Ajaccio
# AwayTeam       Nimes
# FTHG               2
# FTAG               1
# FTR                H
# Name: 256, dtype: object
# ...
